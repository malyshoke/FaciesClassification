# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.colors as colors, ListedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, recall_score, precision_score, classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
plt.style.use('seaborn-paper')

# %%
print("numpy:", np.__version__)
print("pandas:", pd.__version__)
# Out:
# numpy: 1.26.4
# pandas: 1.4.0

# %%
df = pd.read_csv('../data/facies_vectors.csv')

# %%
df
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 0          3     A1 SH        SHRIMPLIN  2793.0  77.450      0.664     9.900
# 1          3     A1 SH        SHRIMPLIN  2793.5  78.260      0.661    14.200
# 2          3     A1 SH        SHRIMPLIN  2794.0  79.050      0.658    14.800
# 3          3     A1 SH        SHRIMPLIN  2794.5  86.100      0.655    13.900
# 4          3     A1 SH        SHRIMPLIN  2795.0  74.580      0.647    13.500
# ...      ...       ...              ...     ...     ...        ...       ...
# 4144       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 4145       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 4146       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 4147       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 4148       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
#        PHIND     PE  NM_M  RELPOS
# ...

# %% [markdown]
# Описание столбцов
# 1. __(GR)__: этот каротажный инструмент измеряет гамма-излучение из пласта. Хороший показатель для определения содержания сланца.<br>
# 2. __(ILD_log10)__: это измерение удельного сопротивления, которое применяется для определения содержания флюидов в пласте.<br>
# 3. __(PE)__: каротаж на основе фотоэлектрического эффекта может быть использован для определения литологии (минерального состава породы).<br>
# 4. __(DeltaPHI)__: Phi - это индекс пористости в петрофизике. Для измерения пористости существует несколько методов, таких как нейтронный и плотностной. Здесь приведены различия между ними.<br>
# 5. __(PNHIND)__: среднее значение нейтронного и плотностного каротажа.<br>
# 6. __(NM_M)__ :неморской морской индикатор <br>
# 7. __(RELPOS)__: относительное положение <br>
#
# Девять дискретных фаций (классов пород) следующие:
# 1. __(SS)__   неморской песчаник
# 2. __(CSiS)__ Неморской грубый алевролит
# 3. __(FSiS)__ Неморской мелкозернистый алевролит
# 4. __(SiSH)__ Морские алевролиты и сланцы
# 5. __(MS)__   Грязевик (известняк)
# 6. __(WS)__   Известняк (известняк)
# 7. __(D)__    Доломит
# 8. __(PS)__   Пакстоун-зернистый камень (известняк)
# 9. __(BS)__   Филлоидно-водорослевый бафлстоун (известняк)
#
# Фации, их сокращенные метки и приблизительные соседи.
#
# Фации |Метки| Соседние фации
# :---: | :---: |:--:
# 1 |SS| 2
# 2 |CSiS| 1,3
# 3 |FSiS| 2
# 4 |SiSh| 5
# 5 |MS| 4,6
# 6 |WS| 5,7
# 7 |D| 6,8
# 8 |PS| 6,7,9
# 9 |BS| 7,8

# %% [markdown]
# #### Просмотр описательной статистики датасета

# %%
df.describe()
# Out:
#             Facies        Depth           GR    ILD_log10     DeltaPHI  \
# count  4149.000000  4149.000000  4149.000000  4149.000000  4149.000000
# mean      4.503254  2906.867438    64.933985     0.659566     4.402484
# std       2.474324   133.300164    30.302530     0.252703     5.274947
# min       1.000000  2573.500000    10.149000    -0.025949   -21.832000
# 25%       2.000000  2821.500000    44.730000     0.498000     1.600000
# 50%       4.000000  2932.500000    64.990000     0.639000     4.300000
# 75%       6.000000  3007.000000    79.438000     0.822000     7.500000
# max       9.000000  3138.000000   361.150000     1.800000    19.312000
#
#              PHIND           PE         NM_M       RELPOS
# count  4149.000000  3232.000000  4149.000000  4149.000000
# mean     13.201066     3.725014     1.518438     0.521852
# std       7.132846     0.896152     0.499720     0.286644
# min       0.550000     0.200000     1.000000     0.000000
# ...

# %%
df.describe(include = ['object'])
# Out:
#        Formation       Well Name
# count       4149            4149
# unique        14              10
# top         C LM  CROSS H CATTLE
# freq         662             501

# %% [markdown]
# Нахождение пропущенных значений

# %%
df.isna().sum()
# Out:
# Facies         0
# Formation      0
# Well Name      0
# Depth          0
# GR             0
# ILD_log10      0
# DeltaPHI       0
# PHIND          0
# PE           917
# NM_M           0
# RELPOS         0
# dtype: int64

# %%
df['PE'] = df['PE'].fillna(df['PE'].mean())

# %%
#Распределение количества записей по каждой из скважин
df['Well Name'].value_counts()
# Out:
# CROSS H CATTLE     501
# SHRIMPLIN          471
# ALEXANDER D        466
# NEWBY              463
# LUKE G U           461
# SHANKLE            449
# KIMZEY A           439
# NOLAN              415
# CHURCHMAN BIBLE    404
# Recruit F9          80
# Name: Well Name, dtype: int64

# %% [markdown]
# Пропущенные значения в столбце __"Фотоэлектрический эффект"__

# %% [markdown]
# Присвоение цветов и названий каждой горной породе

# %%
facies_labels = ['SS', 'CSiS', 'FSiS', 'SiSh', 'MS', 'WS', 'D', 'PS', 'BS']

df['FaciesLabels'] = df['Facies'].apply(lambda x: facies_labels[x-1])

# %%
df
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 0          3     A1 SH        SHRIMPLIN  2793.0  77.450      0.664     9.900
# 1          3     A1 SH        SHRIMPLIN  2793.5  78.260      0.661    14.200
# 2          3     A1 SH        SHRIMPLIN  2794.0  79.050      0.658    14.800
# 3          3     A1 SH        SHRIMPLIN  2794.5  86.100      0.655    13.900
# 4          3     A1 SH        SHRIMPLIN  2795.0  74.580      0.647    13.500
# ...      ...       ...              ...     ...     ...        ...       ...
# 4144       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 4145       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 4146       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 4147       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 4148       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
# ...

# %%
# Определение цветов для каждой фации
facies_colors = ['#F4D03F', '#F5B041','#DC7633','#6E2C00',
                 '#1B4F72','#2E86C1', '#AED6F1', '#A569BD', '#196F3D']

# Получение количества каждой фации
facies_counts = df['FaciesLabels'].value_counts()

# Создание столбчатой диаграммы с указанием цвета для каждой фации
plt.bar(facies_counts.index, facies_counts.values, color=[facies_label_map[f] for f in facies_counts.index])
plt.title('Facies distribution')
plt.xlabel('Facies')
plt.ylabel('Value counts')

plt.show()

# %%
corr = df.iloc[:, 1:].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %%
df.dtypes
# Out:
# Facies            int64
# Formation        object
# Well Name        object
# Depth           float64
# GR              float64
# ILD_log10       float64
# DeltaPHI        float64
# PHIND           float64
# PE              float64
# NM_M              int64
# RELPOS          float64
# FaciesLabels     object
# dtype: object

# %% [markdown]
# #### Исследование численных признаков по каждой категории

# %% [markdown]
# Boxplots позволяют увидеть различия в распределении значений признака между разными классами. Если различия между классами по какому-либо признаку существенны, это может указывать на то, что этот признак будет хорошим предиктором для классификации.

# %%
#Создаем словарь, сопоставляющий каждой фасции ее цвет и название
facies_color_map = {'SS': '#F4D03F', 'CSiS': '#F5B041', 'FSiS': '#DC7633',
                    'SiSh': '#6E2C00', 'MS': '#1B4F72', 'WS': '#2E86C1',
                    'D': '#AED6F1', 'PS': '#A569BD', 'BS': '#196F3D'}
#Ящики с усами
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_columns[1:]:
    if col != 'NM_M':
        fig = plt.figure()
        fig.set_size_inches(16, 10)

        sns.boxplot(y=col, x=df['FaciesLabels'].astype('category'), data=df, palette=facies_color_map)
        plt.show()

# %% [markdown]
# График плотности вероятнопсти для иллюстрации того, какие значения числовой переменной более вероятны для каждой из категорий.
# На графике каждая кривая представляет собой оценку плотности вероятности для определенной категории. Площадь под кривой для каждой категории равна 1, что означает, что вероятность выбора любого значения переменной из данной категории равна 1.

# %%
for col in numeric_columns[1:]:
    plt.figure(figsize=(10, 6))
    sns.kdeplot(data=df, x=col, hue='FaciesLabels', fill=True, common_norm=False, palette=facies_color_map, alpha=0.5)
    plt.title(f'Density Plot of {col} by Facies')
    plt.xlabel(col)
    plt.ylabel('Density')
    
    #Создаем легенду с названиями фасций
    legend_labels = [facies_legend_map[color] for color in facies_color_map.values()]
    plt.legend(title='Facies', labels=legend_labels)
    
    plt.show()
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df.drop(['Facies', 'NM_M', 'RELPOS', 'Depth'], axis=1), 
             hue='FaciesLabels', 
             diag_kind='hist', 
             palette=facies_color_map)

plt.show()

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

for col in categorical_columns: 
    if col != 'FaciesLabels':
        g = sns.catplot(x=col, kind='count', col='FaciesLabels', data=df, sharey=False)
        g.set_xticklabels(rotation=60)

# %%
# 1=sandstone  2=c_siltstone   3=f_siltstone 
# 4=marine_silt_shale 5=mudstone 6=wackestone 7=dolomite
# 8=packstone 9=bafflestone
def compare_facies_plot(logs, compadre, facies_colors):
    """plot the facies plot as a function of depth for both the prediction
       and the actual lithofacies labels.
    """
   
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster1 = np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    cluster2 = np.repeat(np.expand_dims(logs[compadre].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=7, figsize=(9, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.ILD_log10, logs.Depth, '-')
    ax[2].plot(logs.DeltaPHI, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.PHIND, logs.Depth, '-', color='r')
    ax[4].plot(logs.PE, logs.Depth, '-', color='black')
    im1 = ax[5].imshow(cluster1, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    im2 = ax[6].imshow(cluster2, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[6])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im2, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-2):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
        
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("ILD_log10")
    ax[1].set_xlim(logs.ILD_log10.min(),logs.ILD_log10.max())
    ax[2].set_xlabel("DeltaPHI")
    ax[2].set_xlim(logs.DeltaPHI.min(),logs.DeltaPHI.max())
    ax[3].set_xlabel("PHIND")
    ax[3].set_xlim(logs.PHIND.min(),logs.PHIND.max())
    ax[4].set_xlabel("PE")
    ax[4].set_xlim(logs.PE.min(),logs.PE.max())
    ax[5].set_xlabel('Facies')
    ax[6].set_xlabel(compadre)
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    ax[6].set_xticklabels([])
    f.suptitle('Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)

# %%
def make_facies_log_plot(logs, facies_color_map, feature_names):
    logs = logs.sort_values(by='Depth')
    
    top = logs['Depth'].min()
    bottom = logs['Depth'].max()
    
    cluster = np.repeat(np.expand_dims(logs['Facies'].values, 1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=len(feature_names)+1, figsize=(8, 12))
    colors = ['black', 'blue', 'red', 'brown', 'green']
    for i, (feature_name, color) in enumerate(zip(feature_names, colors)):
        ax[i].plot(logs[feature_name], logs.Depth, '-', color = color)
        ax[i].set_ylim(top, bottom)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].set_xlabel(feature_name)
        ax[i].set_xlim(logs[feature_name].min(), logs[feature_name].max())
        ax[i].locator_params(axis='x', nbins=3)
        ax[i].set_yticklabels([]) if i > 0 else None
    
    im = ax[-1].imshow(cluster, interpolation='none', aspect='auto',
                       cmap=ListedColormap(list(facies_color_map.values()), 'indexed'),
                       vmin=1, vmax=9)
    
    divider = make_axes_locatable(ax[-1])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar = plt.colorbar(im, cax=cax)
    facies_labels = list(facies_color_map.keys())
    cbar.set_label((17*' ').join([f' {label} ' for label in facies_labels]))
    cbar.set_ticks(range(0, 1))
    cbar.set_ticklabels('')
    
    ax[-1].set_xlabel('Facies')
    ax[-1].set_yticklabels([])
    ax[-1].set_xticklabels([])
    f.suptitle('Well: %s' % logs.iloc[0]['Well Name'], fontsize=14, y=0.94)
    
    plt.show()

# %%
feature_names = ["GR", "DeltaPHI", "PHIND", "ILD_log10", "PE"]
make_facies_log_plot(df[df['Well Name'] == 'SHRIMPLIN'], facies_color_map, feature_names)

# %% [markdown]
# ### Применение моделей

# %%
X = df[['Depth', 'GR', 'ILD_log10',
       'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS']]
y = df['Facies']

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    random_state=0, 
                                                    test_size=0.2)

# %%
from sklearn.multiclass import OneVsRestClassifier ### Один против всех
from sklearn.linear_model import SGDClassifier ### 

SGDClassifier(loss='log') ### max(0; 1-M)

pipe = Pipeline([("scaler", StandardScaler()),
                 ("one_vs_all", OneVsRestClassifier(SGDClassifier()))])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('one_vs_all', OneVsRestClassifier(estimator=SGDClassifier()))])

# %%
np.mean((pipe.predict(X_test) == y_test)), np.mean((pipe.predict(X_train) == y_train))
# Out:
# (0.4867469879518072, 0.4953299186501958)

# %%
### Переберем различные параметры базовых моделей

from sklearn.model_selection import GridSearchCV

param_grid = {
    'one_vs_all__estimator__loss': ['hinge', 'log', 'modified_huber',
                                    'squared_hinge', 'perceptron'],
    
    'one_vs_all__estimator__penalty': ['l1', 'l2', 'elasticnet'],
    
    'one_vs_all__estimator__alpha': [0.001, 0.01, 0.1, 0.5, 1, 10]
}

from sklearn.model_selection import PredefinedSplit

test_fold = [0 if x in X_train.index else -1 for x in X.index]
ps = PredefinedSplit(test_fold)

search = GridSearchCV(pipe, param_grid, cv=ps)

search.fit(X, y)

print(f"Best parameter (CV score={search.best_score_:.5f}):")
print(search.best_params_)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:723: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:723: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:723: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:723: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# ...

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# Определяем параметры для поиска
param_grid = {
    'svm__kernel': ['linear', 'rbf', 'poly'],
    'svm__C': [0.1, 1, 10],
    'svm__gamma': ['scale', 'auto'],
}

# Создаем объект SVM
svm = SVC()

# Создаем конвейер для объединения стандартизации и SVM
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', svm)
])

# Создаем объект GridSearchCV
search = GridSearchCV(pipe, param_grid, cv=ps)

# Запускаем поиск
search.fit(X, y)

# Выводим лучшие параметры и оценку
print(f"Best parameter (CV score={search.best_score_:.5f}):")
print(search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1472\1295556270.py in <module>
#      21
#      22 # Создаем объект GridSearchCV
# ---> 23 search = GridSearchCV(pipe, param_grid, cv=ps)
#      24
#      25 # Запускаем поиск
#
# NameError: name 'ps' is not defined

# %% [markdown]
# #### Случайный лес

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Создаем модель случайного леса
rf_classifier = RandomForestClassifier(random_state=42)

# Определяем параметры для поиска для случайного леса
rf_param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Создаем объект GridSearchCV для случайного леса
rf_search = GridSearchCV(rf_classifier, rf_param_grid, cv=5)

# Запускаем поиск для случайного леса
rf_search.fit(X_train, y_train)

# Выводим лучшие параметры и оценку для случайного леса
print("Best parameters for Random Forest:", rf_search.best_params_)
print("Accuracy of Random Forest:", rf_search.best_score_)
# Out:
# Best parameters for Random Forest: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Accuracy of Random Forest: 0.770410601682749

# %%
from sklearn.model_selection import GroupShuffleSplit

# Создаем объект GroupShuffleSplit для кросс-валидации с учетом групп
gss = GroupShuffleSplit(n_splits=5, test_size=0.2, random_state=42)

# Инициализируем пустые списки для хранения результатов
best_params_list = []
best_score_list = []

# Итерируемся по разбиениям
for train_index, test_index in gss.split(X, y, groups=df['Well Name']):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Создаем модель случайного леса
    rf_classifier = RandomForestClassifier(random_state=42)

    # Определяем параметры для поиска для случайного леса
    rf_param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }

    # Создаем объект GridSearchCV для случайного леса
    rf_search = GridSearchCV(rf_classifier, rf_param_grid, cv=5)

    # Запускаем поиск для случайного леса
    rf_search.fit(X_train, y_train)

    # Сохраняем лучшие параметры и оценку
    best_params_list.append(rf_search.best_params_)
    best_score_list.append(rf_search.best_score_)

# Выводим лучшие параметры и оценку для каждого разбиения
for i in range(len(best_params_list)):
    print(f"Best parameters for split {i + 1}:", best_params_list[i])
    print(f"Accuracy of split {i + 1}:", best_score_list[i])

# %%
from sklearn.model_selection import GroupShuffleSplit

# Создаем объект GroupShuffleSplit для кросс-валидации с учетом групп
gss = GroupShuffleSplit(n_splits=5, test_size=0.2, random_state=42)

# Создаем объект GridSearchCV для случайного леса с указанием GroupShuffleSplit в качестве cv
rf_search = GridSearchCV(rf_classifier, rf_param_grid, cv=gss)

# Запускаем поиск для случайного леса
rf_search.fit(X, y, groups=df['Well Name'])

# Выводим лучшие параметры и оценку
print("Best parameters for Random Forest:", rf_search.best_params_)
print("Accuracy of Random Forest:", rf_search.best_score_)

# %% [markdown]
# #### Градиентный бустинг

# %%
# Создаем модель градиентного бустинга
gb_classifier = GradientBoostingClassifier(random_state=42)

# Определяем параметры для поиска для градиентного бустинга
gb_param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 5, 7]
}

# Создаем объект GridSearchCV для градиентного бустинга
gb_search = GridSearchCV(gb_classifier, gb_param_grid, cv=5)

# Запускаем поиск для градиентного бустинга
gb_search.fit(X_train, y_train)

# Выводим лучшие параметры и оценку для градиентного бустинга
print("Best parameters for Gradient Boosting:", gb_search.best_params_)
print("Accuracy of Gradient Boosting:", gb_search.best_score_)
# Out:
# Best parameters for Gradient Boosting: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 300}
# Accuracy of Gradient Boosting: 0.7761339475549256

# %%
X_train
# Out:
#        Depth      GR  ILD_log10  DeltaPHI    PHIND        PE  NM_M  RELPOS
# 3923  3006.5  64.938   0.771000    -9.770  34.0370  2.199000     1   0.083
# 4053  3075.0  45.719   0.516000     0.398  16.1060  5.352000     2   0.300
# 2155  3072.5  28.892   0.909000     6.131  13.5605  3.725014     2   0.872
# 620   2963.0  38.930   0.970000     6.000   6.9600  3.725014     2   0.333
# 2410  2636.5  62.166   0.879497    -1.700  17.8500  3.542000     1   0.833
# ...      ...     ...        ...       ...      ...       ...   ...     ...
# 1033  2823.0  85.690   1.133000     0.100   3.9650  5.000000     2   0.186
# 3264  3072.5  40.531   0.184000     1.033  17.4240  4.894000     2   0.383
# 1653  2744.0  61.710   0.596000     3.000   9.1000  3.400000     1   0.870
# 2607  2735.5  77.631   0.284656     6.300  15.1500  2.845000     1   0.500
# 2732  2812.0  30.956   1.107278    -0.300   5.7500  4.557000     2   0.882
#
# [3319 rows x 8 columns]

# %% [markdown]
# #### Нейронная сеть

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Dense, Activation, Dropout

# Определение архитектуры модели
def create_model(input_shape, num_classes, units=64):
    model = models.Sequential([
        Dense(units, input_shape=input_shape),
        Activation("relu"),
        Dropout(0.3),
        Dense(units),
        Activation("relu"),
        Dropout(0.3),
        Dense(num_classes),
        Activation("softmax"),    
    ])
    return model

# Задаем размерности входных данных и количество классов
input_shape = (8,)  # 8 признаков
num_classes = 9     # 9 классов

# Создаем модель
model = create_model(input_shape, num_classes)

# Компилируем модель
model.compile(optimizer="adagrad",
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Выводим информацию о модели
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 64)                576
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  activation_7 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 9)                 585
#
#  activation_8 (Activation)   (None, 9)                 0
#
# ...
# Total params: 5321 (20.79 KB)
# Trainable params: 5321 (20.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tqdm import tqdm

# Определяем количество эпох обучения
epochs = 200

# Создаем пустой список для сохранения истории метрик обучения
history = []

# Конвертируем целевую переменную в one-hot encoding
from tensorflow.keras.utils import to_categorical

y_one_hot = to_categorical(y - 1, num_classes=9)

# Цикл обучения
for epoch in range(epochs):
    # Запускаем обучение модели и сохраняем историю обучения
    epoch_history = model.fit(X, y_one_hot, epochs=1, validation_split=0.2, verbose=0)
    # Добавляем метрики текущей эпохи в общую историю
    history.append(epoch_history.history)
    # Отображаем прогресс обучения с помощью tqdm
    tqdm.write(f"Epoch {epoch + 1}/{epochs}, Loss: {epoch_history.history['loss'][0]}, Accuracy: {epoch_history.history['accuracy'][0]}, Validation Loss: {epoch_history.history['val_loss'][0]}, Validation Accuracy: {epoch_history.history['val_accuracy'][0]}")
# Out:
# Epoch 1/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# Epoch 2/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# Epoch 3/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# Epoch 4/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# Epoch 5/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# Epoch 6/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# Epoch 7/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# Epoch 8/200, Loss: nan, Accuracy: 0.07833684980869293, Validation Loss: nan, Validation Accuracy: 0.00963855441659689
# ...

# %%
# Получаем значения потерь и точности из истории обучения
train_loss = [epoch['loss'][0] for epoch in history]
val_loss = [epoch['val_loss'][0] for epoch in history]
train_accuracy = [epoch['sparse_categorical_accuracy'][0] for epoch in history]
val_accuracy = [epoch['val_sparse_categorical_accuracy'][0] for epoch in history]

# Нарисуем график потерь
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Нарисуем график точности
plt.figure(figsize=(10, 5))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import matplotlib.pyplot as plt

# Преобразуем y в one-hot encoding с помощью встроенной функции в Keras
from tensorflow.keras.utils import to_categorical
y_ohe = to_categorical(y - 1, num_classes=9)

# Разделим данные на обучающий и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X, y_ohe, test_size=0.2, random_state=42)

# Определим архитектуру модели
units = 256
model = Sequential([
    Dense(units, input_shape=(8,)),
    Activation("relu"),
    Dropout(0.3),
    Dense(units),
    Activation("relu"),
    Dropout(0.3),
    Dense(9),  # Вероятности для 9 классов
    Activation("softmax"),
])

# Скомпилируем модель
model.compile(loss='categorical_crossentropy', optimizer="adagrad", metrics=['accuracy'])

# Create an empty list to store the training history
history = []

# Train the model
for epoch in tqdm(range(epochs)):
    # Run a single epoch of training
    epoch_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=10, epochs=1, verbose=0)
    # Append the metrics of the current epoch to the history list
    history.append(epoch_history.history)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [04:05<00:00,  1.23s/it]

# %%
train_accuracy
# Out:
# [0.06357336789369583,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
#  0.06447724997997284,
# ...

# %%
train_accuracy = [epoch['accuracy'][0] for epoch in history]
val_accuracy = [epoch['val_accuracy'][0] for epoch in history]

# Plot the accuracy values
plt.plot(train_accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot training history
def plot_history(history):
    # Extracting training and validation loss
    loss = [epoch['loss'][0] for epoch in history]
    val_loss = [epoch['val_loss'][0] for epoch in history]

    # Extracting training and validation accuracy
    accuracy = [epoch['accuracy'][0] for epoch in history]
    val_accuracy = [epoch['val_accuracy'][0] for epoch in history]

    # Plotting training and validation loss
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plotting training and validation accuracy
    plt.subplot(1, 2, 2)
    plt.plot(accuracy, label='Training Accuracy')
    plt.plot(val_accuracy, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Show plot
    plt.tight_layout()
    plt.show()

# Plot training history
plot_history(history)

# %%
from tqdm import tqdm

# Определяем количество эпох обучения
epochs = 200

# Создаем пустой список для сохранения истории метрик обучения
history = []

# Разделяем данные на обучающий и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X, y_ohe, test_size=0.2, random_state=42)

# Определим архитектуру модели с увеличенным количеством нейронов и дополнительным слоем
units = 512  # Увеличили количество нейронов в слоях до 512
model = Sequential([
    Dense(units, input_shape=(8,), activation='relu'),  # Изменяем количество нейронов во входном слое
    Dense(units, activation='relu'),  # Изменяем количество нейронов во втором скрытом слое
    Dropout(0.3),
    Dense(2*units, activation='relu'),  # Добавляем третий скрытый слой с тем же количеством нейронов
    Dense(9, activation='softmax')  # Оставляем выходной слой без изменений
])

# Скомпилируем модель
model.compile(loss='categorical_crossentropy', optimizer='adagrad', metrics=['accuracy'])

# Обучаем модель с отслеживанием процесса обучения с помощью tqdm
for epoch in tqdm(range(epochs), desc="Training", unit="epoch"):
    epoch_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=10, epochs=1, verbose=0)
    history.append(epoch_history.history)
# Out:
# Training: 100%|███████████████████████████████████████████████████████████████████| 200/200 [15:41<00:00,  4.71s/epoch]

# %%
train_accuracy = [epoch['accuracy'][0] for epoch in history]
val_accuracy = [epoch['val_accuracy'][0] for epoch in history]

# Plot the accuracy values
plt.plot(train_accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
